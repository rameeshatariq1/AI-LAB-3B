# %% [markdown]
# ### _**Name: Rameesha Tariq**_
# ### _**Roll no: SU92-BSAI-F24-118**_
# ### _**Lab task - 09**_

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (30, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  30.000000      30.000000     30.000000      30.000000     30.000000
# mean   15.500000       5.730000      2.963333       3.783333      1.183333
# std     8.803408       0.919951      0.439030       1.861976      0.787875
# min     1.000000       4.400000      2.000000       1.300000      0.100000
# 25%     8.250000       4.925000      2.725000       1.500000      0.225000
# 50%    15.500000       5.600000      3.000000       4.100000      1.300000
# 75%    22.750000       6.450000      3.275000       5.475000      1.800000
# max    30.000000       7.600000      3.900000       6.600000      2.500000

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             30 non-null     int64
#  1   SepalLengthCm  30 non-null     float64
#  2   SepalWidthCm   30 non-null     float64
#  3   PetalLengthCm  30 non-null     float64
#  4   PetalWidthCm   30 non-null     float64
#  5   Species        30 non-null     object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 1.5+ KB

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        10
# Iris-versicolor    10
# Iris-virginica     10
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.pairplot(df, hue='Species')
